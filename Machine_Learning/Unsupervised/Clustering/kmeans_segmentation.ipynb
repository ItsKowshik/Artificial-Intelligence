# %% [markdown]
# ### Image segmentation using Kmeans algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#Read and import the image
image = cv2.imread('./data/monarch.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
pixel_vals = image.reshape((-1,3))
pixel_vals = np.float32(pixel_vals)
print(pixel_vals)
# Out:
# [[115. 189.  66.]
#  [112. 186.  65.]
#  [110. 181.  63.]
#  ...
#  [125. 158.  54.]
#  [123. 155.  56.]
#  [119. 150.  56.]]

# %%
#Set criteria for training
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.90)
#The kmeans algorithm
k = 3
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
print(centers)
print(labels.shape)
# Out:
# [[234.2974   119.014946  42.027397]
#  [ 37.130966  42.481056  29.28757 ]
#  [107.54552  152.50557   66.53671 ]]
# (50325, 1)

# %%
#Label each pixel
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]

# %%
segmented_image = segmented_data.reshape((image.shape))
plt.imshow(segmented_image)
